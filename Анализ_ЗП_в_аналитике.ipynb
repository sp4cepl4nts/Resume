# %% [markdown]
# <a href="https://colab.research.google.com/github/sp4cepl4nts/Resume/blob/main/%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%97%D0%9F_%D0%B2_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !gdown --id 1iMMDp1lciPbOA4TIdFJm6a6N9A41jwgu
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1iMMDp1lciPbOA4TIdFJm6a6N9A41jwgu
# To: /content/datasortednotsplited.xlsx
# 100% 2.49M/2.49M [00:00<00:00, 127MB/s]

# %%
df = pd.read_excel('datasortednotsplited.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20906 entries, 0 to 20905
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              20906 non-null  int64
#  1   Название вакансии       20906 non-null  object
#  2   Дата публикации         20906 non-null  datetime64[ns]
#  3   Работодатель            20906 non-null  object
#  4   Ключевые навыки         20906 non-null  object
#  5   Название региона        20906 non-null  object
#  6   График работы           20906 non-null  object
#  7   Опыт работы             20906 non-null  object
#  8   Название специальности  20906 non-null  object
#  9   Заработная плата        20906 non-null  int64
#  10  Вид трудоустройства     20906 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 1.8+ MB

# %% [markdown]
# Количественные признаки:
# Заработная плата
#
#
# Категориальные признаки:
# Название региона
# Работодатель
# Требования к знанию языков
# Вид трудоустройства
# Название специальности
# Опыт работы
# График работы

# %%
df.head()
# Out:
#    Unnamed: 0    Название вакансии Дата публикации  \
# 0           0          Аналитик 1С      2024-02-13
# 1           1  Начинающий аналитик      2024-03-13
# 2           2       Консультант 1С      2024-02-15
# 3           3      Бизнес-аналитик      2024-02-19
# 4           4      Бизнес-аналитик      2024-04-25
#
#                                         Работодатель  \
# 0                                         Первый Бит
# 1  Крупнейший дистрибьютор продуктов питания в Ал...
# 2                                        Эй-Пи Трейд
# 3                                           Мария-Ра
# 4                                           ТЕХНЕЗИС
#
#                                      Ключевые навыки Название региона  \
# 0  ['1С: Предприятие', 'SQL', 'Аналитическое мышл...   Алтайский край
# 1                                      ['Не укзаны']   Алтайский край
# 2  ['1С: Бухгалтерия', '1С: Предприятие', '1С: Уп...   Алтайский край
# ...

# %%
df1 = df.copy()

# %% [markdown]
# ИСКЛЮЧЕНИЕ ВЫБРОСОВ ПО ЗП

# %%
df1 = df1[df1['Заработная плата'] >= 10000]

# %%
df1 = df1[df1['Заработная плата'] < 300000]

# %%
df1.reset_index(drop = True)
# Out:
#       Unnamed: 0                                  Название вакансии  \
# 0              0                                        Аналитик 1С
# 1              1                                Начинающий аналитик
# 2              2                                     Консультант 1С
# 3              3                                    Бизнес-аналитик
# 4              6  Специалист отдела мониторинга доступности меди...
# ...          ...                                                ...
# 6065       20892                             Аналитик 1С (удаленно)
# 6066       20893                                           Аналитик
# 6067       20896                         Бизнес-аналитик в IT-сфере
# 6068       20898                 Аналитик/Координатор отдела продаж
# 6069       20900           Ведущий специалист по нормированию труда
#
#      Дата публикации                                       Работодатель  \
# 0         2024-02-13                                         Первый Бит
# ...

# %%
salary = df1['Заработная плата']

# %%
salary.describe()
# Out:
# count      6070.000000
# mean     113156.320264
# std       64014.188588
# min       12000.000000
# 25%       61837.500000
# 50%      100000.000000
# 75%      150000.000000
# max      298000.000000
# Name: Заработная плата, dtype: float64

# %%
plt.boxplot(salary)
plt.ylabel("Заработная плата, ₽")
plt.show()

# %%
plt.hist(salary, bins = 10)
plt.ylabel('Количество вакансий')
plt.xlabel("Заработная плата, ₽")
plt.show()

# %%
country_top_10 = df1['Название региона'].value_counts()[:10]
country_top_10
# Out:
# Название региона
# Москва                   1816
# Санкт-Петербург           846
# Свердловская область      341
# Республика Татарстан      281
# Краснодарский край        262
# Новосибирская область     227
# Нижегородская область     204
# Самарская область         169
# Ростовская область        155
# Воронежская область       147
# Name: count, dtype: int64

# %%
country_top = ['Москва', 'Санкт-Петербург', 'Свердловская область', 'Республика Татарстан', 'Краснодарский край', 'Новосибирская область', 'Нижегородская область', 'Самарская область', 'Ростовская область', 'Воронежская область']

# %%
filtered_dataset = df1[df1['Название региона'].isin(country_top)]

# %%
sns.boxplot(x='Название региона', y="Заработная плата", data=filtered_dataset)
plt.xticks(rotation=90)
plt.ylabel("Заработная плата, ₽")
plt.show()

# %%
df1.groupby('Название специальности')['Заработная плата'].median()
# Out:
# Название специальности
# BI-аналитик, аналитик данных    100000.0
# Аналитик                         80000.0
# Бизнес-аналитик                 100000.0
# Дата-сайентист                  120000.0
# Системный аналитик              150000.0
# Name: Заработная плата, dtype: float64

# %%
sns.boxplot(x='Название специальности', y="Заработная плата", data=df1)
plt.xticks(rotation=30)
plt.ylabel("Заработная плата, ₽")
plt.show()

# %%
df1['Работодатель'].value_counts()
# Out:
# Работодатель
# Первый Бит                     103
# Aston                           85
# МАГНИТ, Розничная сеть          66
# Алабуга, ОЭЗ ППТ                59
# Ростелеком                      45
#                               ...
# Т1                               1
# Compensair LTD                   1
# Территория 2.0                   1
# Algos Capital                    1
# Метелица Плюс, Торговый дом      1
# Name: count, Length: 3022, dtype: int64

# %%
df1.groupby('Работодатель')['Заработная плата'].median()
# Out:
# Работодатель
# 1+1                                    120000.0
# 1-й Советник                           120000.0
# 100Балльный Репетитор                  180000.0
# 101 Интернет                           100000.0
# 105                                    130000.0
#                                          ...
# Ястро-Агро                              40000.0
# Яхонт                                   60000.0
# Яшин&Партнёры                           50000.0
# билайн                                  84000.0
# фирма Агрокомплекс им. Н.И. Ткачева    120000.0
# Name: Заработная плата, Length: 3022, dtype: float64

# %%
employer_top_10 = df['Работодатель'].value_counts()[:10]

# %%
employer_top_10
# Out:
# Работодатель
# СБЕР                       876
# Aston                      350
# Т1                         320
# МАГНИТ, Розничная сеть     188
# Газпром нефть              182
# Первый Бит                 169
# Лига Цифровой Экономики    163
# МТС                        154
# Компания КомЛайн           153
# IBS                        143
# Name: count, dtype: int64

# %%
employer_top = ['Первый Бит', 'Aston', 'МАГНИТ, Розничная сеть', 'Т1', 'Газпром нефть', 'Лига Цифровой Экономики', 'МТС' , 'Компания КомЛайн', 'СБЕР', 'IBS']

# %%
filtered_dataset2 = df1[df1['Работодатель'].isin(employer_top)]

# %%
filtered_dataset2
# Out:
#        Unnamed: 0                         Название вакансии Дата публикации  \
# 0               0                               Аналитик 1С      2024-02-13
# 9               9                               Аналитик 1С      2024-03-04
# 12             12                               Аналитик 1С      2024-03-21
# 13             13                               Аналитик 1С      2024-03-01
# 17             17                               Аналитик 1C      2024-04-05
# ...           ...                                       ...             ...
# 20872       20872                                  Аналитик      2024-03-15
# 20888       20888                                  Аналитик      2024-03-15
# 20889       20889               Системный аналитик (стажер)      2024-04-04
# 20892       20892                    Аналитик 1С (удаленно)      2024-02-12
# 20900       20900  Ведущий специалист по нормированию труда      2024-02-21
#
#                  Работодатель  \
# ...

# %%
filtered_dataset2.groupby('Работодатель')['Заработная плата'].median()
# Out:
# Работодатель
# Aston                      80000.0
# МАГНИТ, Розничная сеть     75000.0
# МТС                        58500.0
# Первый Бит                100000.0
# СБЕР                      120000.0
# Т1                         60000.0
# Name: Заработная плата, dtype: float64

# %%
sns.boxplot(x='Работодатель', y="Заработная плата", data=filtered_dataset2)
plt.xticks(rotation=90)
plt.ylabel("Заработная плата, ₽")
plt.show()

# %%
df1.groupby('Вид трудоустройства')['Заработная плата'].median()
# Out:
# Вид трудоустройства
# Временная занятость    100000.0
# Полная занятость       100000.0
# Стажировка              73750.0
# Частичная занятость     66000.0
# Name: Заработная плата, dtype: float64

# %%
sns.boxplot(x='Вид трудоустройства', y="Заработная плата", data=df1)
plt.xticks(rotation=30)
plt.ylabel("Заработная плата, ₽")
plt.show()

# %%
df1.groupby('Опыт работы')['Заработная плата'].median()
# Out:
# Опыт работы
# 0       60000.0
# 1-3     94000.0
# 3-6    180000.0
# 6-     200000.0
# Name: Заработная плата, dtype: float64

# %%
sns.boxplot(x='Опыт работы', y="Заработная плата", data=df1)
plt.xticks(rotation=30)
plt.ylabel("Заработная плата, ₽")
plt.show()

# %%
df1.groupby('График работы')['Заработная плата'].median()
# Out:
# График работы
# Вахтовый метод           177500.0
# Гибкий график             80000.0
# Неполный рабочий день     20000.0
# Полный день               89600.0
# Сменный график            60000.0
# Удаленная работа         120000.0
# Name: Заработная плата, dtype: float64

# %%
sns.boxplot(x='График работы', y="Заработная плата", data=df1)
plt.xticks(rotation=30)
plt.ylabel("Заработная плата, ₽")
plt.show()
